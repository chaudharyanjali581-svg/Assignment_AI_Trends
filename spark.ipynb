# %%
import pyspark

# %%
import os
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext,SparkConf

# %%
conf=SparkConf().set("Spark.ui.port","4050")

# %%
import pyspark
sc=pyspark.SparkContext(conf=conf)
spark=SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pyspark
# ----> 2 sc=pyspark.SparkContext(conf=conf)
#       3 spark=SparkSession.builder.getOrCreate()
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pyspark\core\context.py:205, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     199 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     200     raise ValueError(
#     201         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     202         " is not allowed as it is a security risk."
#     203     )
# --> 205 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     206 try:
#     207     self._do_init(
#     208         master,
#     209         appName,
#    (...)    219         memory_profiler_cls,
#     220     )
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pyspark\core\context.py:444, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     442 with SparkContext._lock:
#     443     if not SparkContext._gateway:
# --> 444         SparkContext._gateway = gateway or launch_gateway(conf)
#     445         SparkContext._jvm = SparkContext._gateway.jvm
#     447     if instance:
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
pyspark version
# Out:
#   Cell In[7], line 1
#     pyspark version
#             ^
# SyntaxError: invalid syntax

# %%
import files
files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import files
#       2 files.upload()
#
# ModuleNotFoundError: No module named 'files'

# %%
a=spark.sparkContext.textFile("a_spark.txt")
a.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a=spark.sparkContext.textFile("a_spark.txt")
#       2 a.collect()
#
# NameError: name 'spark' is not defined

# %%
b=a.flatMap(lambda x:x.split(" "))
b.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 b=a.flatMap(lambda x:x.split(" "))
#       2 b.collect()
#
# NameError: name 'a' is not defined
